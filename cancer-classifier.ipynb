# %%
# importing needed libraries
import os
os.environ["OPENBLAS_NUM_THREADS"] = "1"
import numpy as np 
import pandas as pd

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/ml-ai-hackathon-2025/sample_submission.csv
# /kaggle/input/ml-ai-hackathon-2025/train_labels.csv
# /kaggle/input/ml-ai-hackathon-2025/train.csv
# /kaggle/input/ml-ai-hackathon-2025/test.csv

# %%
# loading training data 
train = pd.read_csv('/kaggle/input/ml-ai-hackathon-2025/train.csv')
shape = train.shape
print("shape = ",shape)
train.head(5)
# Out:
# shape =  (400, 14574)
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
# ...

# %%
# loading the labeled data
labeled = pd.read_csv('/kaggle/input/ml-ai-hackathon-2025/train_labels.csv')
shape_labeled = labeled.shape
print('shape = ',shape_labeled)
# Out:
# shape =  (150, 2)

# %%
# labeled and unlabeled data 
labeled_data =  train[train['Class'].notna()]
labeled_data.head(5)
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# ...

# %%
unlabeled_data = train[train['Class'].isna()]
unlabeled_data.head(5)
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# ...

# %%
# class wise amount of labeled data
print(labeled['Class'].value_counts().sort_index())
# Out:
# Class
# 0    26
# 1    26
# 2    56
# 3    15
# 4    27
# Name: count, dtype: int64

# %%
# Preprocessing data
# Checking NaN values
train.count()
# Out:
# Id            400
# gene_1        377
# gene_3        377
# gene_5        359
# gene_7        360
#              ...
# gene_20639    367
# gene_20640    367
# gene_20641    362
# gene_20642    373
# Class         150
# Length: 14574, dtype: int64

# %%
# Handling NaN values in feature columns 
train.describe()
# Out:
#            gene_1      gene_3      gene_5      gene_7      gene_8      gene_9  \
# count  377.000000  377.000000  359.000000  360.000000  366.000000  371.000000
# mean     0.021837    0.035915    0.056641    0.029717    0.037396   -0.008650
# std      1.057056    1.002452    1.080441    1.029455    1.008852    0.867782
# min     -3.155312   -2.419660   -6.138127   -2.853971   -5.737839   -4.079731
# 25%     -0.660768   -0.561155   -0.430800   -0.606470   -0.400367   -0.412866
# 50%     -0.082608   -0.053682    0.028547   -0.203639   -0.012730   -0.004288
# 75%      0.604347    0.536110    0.438748    0.472378    0.437949    0.346295
# max      7.714353    6.495396    5.857435    4.697492    4.776318    5.116117
#
#           gene_10     gene_11     gene_13     gene_14  ...  gene_20634  \
# count  371.000000  370.000000  362.000000  367.000000  ...  376.000000
# mean    -0.031838    0.009048   -0.012285   -0.072535  ...   -0.055299
# ...

# %%
# Importing plotting libraries
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# plotting the gene distribution
#features = train.drop(columns=["Class","Id"])
#for gene in features.columns:
#    plt.figure(figsize=(6, 4))
#    sns.histplot(features[gene], kde=True, bins=30)
#    plt.title(f'Distribution of Gene: {gene}')
#    plt.xlabel('Expression Level')
#    plt.ylabel('Frequency')
#    plt.tight_layout()
#    plt.show()

# %%
# using cross validation to reduce over fitting
# Using semi supervised learning method self_training for unlabeled data
# Using XGBoost model for classification
# Obesreving graphs, best value to fill is mean value
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, f1_score
from xgboost import XGBClassifier
from sklearn.semi_supervised import SelfTrainingClassifier

X_labeled = train.loc[train['Class'].notna(), train.columns.difference(['Id', 'Class'])]
y_labeled = train.loc[train['Class'].notna(), 'Class']

# implementing the cross validation loop
kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
accuracies = []
f1s = []

for fold, (train_idx, val_idx) in enumerate(kf.split(X_labeled, y_labeled), 1):
    print(f"\n🚀 Fold {fold}")
    
    # Split
    X_train_raw = X_labeled.iloc[train_idx]
    X_val_raw = X_labeled.iloc[val_idx]
    y_train = y_labeled.iloc[train_idx]
    y_val = y_labeled.iloc[val_idx]
    
    # Impute with train mean
    mean_vals = X_train_raw.mean()
    X_train_filled = X_train_raw.fillna(mean_vals)
    X_val_filled = X_val_raw.fillna(mean_vals)
    # Prepare unlabeled data
    X_unlabeled = train.loc[train['Class'].isna(), train.columns.difference(['Id', 'Class'])]
    X_unlabeled_filled = X_unlabeled.fillna(mean_vals)
    y_unlabeled = np.full(len(X_unlabeled), -1)

    # Combine
    X_combined = pd.concat([X_train_filled, X_unlabeled_filled], ignore_index=True)
    y_combined = pd.concat([y_train.reset_index(drop=True), pd.Series(y_unlabeled)], ignore_index=True)

    # Model
    base_clf = XGBClassifier(
        tree_method='gpu_hist',    
        objective='multi:softprob',
        num_class=len(np.unique(y_labeled)),
        use_label_encoder=False,
        eval_metric='mlogloss',
        random_state=42,
        n_jobs=-1,
        n_estimators=50,              
        max_depth=3
        )

    self_training_clf = SelfTrainingClassifier(
        base_clf,
        threshold=0.9,
        criterion='k_best',
        k_best=10,
        max_iter=1000,
        verbose=False
        )

    # Fit model
    self_training_clf.fit(X_combined, y_combined)
    # Evaluate
    y_pred = self_training_clf.predict(X_val_filled)
    acc = accuracy_score(y_val, y_pred)
    f1 = f1_score(y_val, y_pred, average='macro')

    print(f"🔹 Fold {fold} Accuracy: {acc:.4f}")
    print(f"🔹 Fold {fold} Macro F1 Score: {f1:.4f}")

    accuracies.append(acc)
    f1s.append(f1)
# Out:
# 🚀 Fold 1
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [05:03:53] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [05:03:55] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# ...

# %%
# final training
from xgboost import XGBClassifier
from sklearn.semi_supervised import SelfTrainingClassifier
import numpy as np
import pandas as pd

# Preparing full labeled and unlabeled data ---
X_labeled_final = train.loc[train['Class'].notna(), train.columns.difference(['Id', 'Class'])]
y_labeled_final = train.loc[train['Class'].notna(), 'Class']

X_unlabeled_final = train.loc[train['Class'].isna(), train.columns.difference(['Id', 'Class'])]
y_unlabeled_final = np.full(len(X_unlabeled_final), -1)

# Filling NaNs using only labeled training stats ---
mean_final = X_labeled_final.mean()
X_labeled_filled = X_labeled_final.fillna(mean_final)
X_unlabeled_filled = X_unlabeled_final.fillna(mean_final)

# Combining for semi-supervised training ---
X_combined_final = pd.concat([X_labeled_filled, X_unlabeled_filled], ignore_index=True)
y_combined_final = pd.concat(
    [y_labeled_final.reset_index(drop=True), pd.Series(y_unlabeled_final)],
    ignore_index=True
)

# Defining and training final model (GPU-accelerated)
base_clf_final = XGBClassifier(
    tree_method='gpu_hist',       
    objective='multi:softprob',
    num_class=len(np.unique(y_labeled_final)),
    use_label_encoder=False,
    eval_metric='mlogloss',
    random_state=42,
    n_jobs=-1,
    n_estimators=50,
    max_depth=3
)

self_training_clf_final = SelfTrainingClassifier(
    base_clf_final,
    threshold=0.9,
    criterion='k_best',
    k_best=10,
    max_iter=1000,
    verbose=True
)

# fitting
self_training_clf_final.fit(X_combined_final, y_combined_final)
# Out:
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [05:13:41] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [05:13:44] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# End of iteration 1, added 10 new labels.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [05:13:46] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
# ...

# %%
# Loading the test data
test = pd.read_csv('/kaggle/input/ml-ai-hackathon-2025/test.csv')
test_shape = test.shape
print("Test_data shape: ",test_shape)
test.head(5)
# Out:
# Test_data shape:  (401, 14573)
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
# ...

# %%
# Handling missing values
id_col_1 = test['Id']
X_test_aligned = test.drop(columns=['Id'])
# Align columns to training feature order
X_test_aligned = X_test_aligned[X_combined_final.columns]
# Fill NaNs using mean from training
X_test_filled = X_test_aligned.fillna(mean_final)

# %%
y_preds = self_training_clf_final.predict(X_test_filled)
# Out:
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [05:15:43] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)

# %%
# creating dataframe
submission = pd.DataFrame({
    'Id': test['Id'],
    'Class': y_preds
})

# %%
# Save to CSV
submission.to_csv('submission.csv', index=False)
print("submission.csv has been created successfully!")
# Out:
# submission.csv has been created successfully!
